# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
games = pd.read_csv("C:\Users\raulz\OneDrive\Área de Trabalho\Estudo\Projetos independentes\Python\Proejto 1\archive.csv")
games.head
# Out:
#   Cell In[2], line 1
#     games = pd.read_csv("C:\Users\raulz\OneDrive\Área de Trabalho\Estudo\Projetos independentes\Python\Proejto 1\archive.csv")
#                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
